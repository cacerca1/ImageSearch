# %%
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
import random
from imagesearch.utils import open_image

# %% [markdown]
# # Data Exploration

# %%
image_folder = '/mnt/osn3/caceres/classes/geological/geological_similarity'

# %%
classes = [ 'andesite', 'gneiss', 'marble', 'quartzite', 'rhyolite', 'schist']

# %%
sizes = []
for i, label in enumerate(classes):
    image_list = glob.glob(image_folder + '/' + label + '/*.jpg')
    print(i, label, len(image_list))
    _, axes = plt.subplots(1,4,figsize=(16,4))
    for i in range(4):
        # load the image
        image = open_image(v[i])
        # convert image to numpy array
        im = np.asarray(image)
        axes.flat[i].imshow(im)
        sizes.append(im.shape)
# Out:
# 0 andesite 5000
# 1 gneiss 5000
# 2 marble 4998
# 3 quartzite 5000
# 4 rhyolite 5000
# 5 schist 5000

# %%
set(sizes)
# Out:
# {(28, 28, 3)}
